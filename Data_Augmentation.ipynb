# %% [markdown]
# Data Augmentation Methods

# %%
import librosa
import os
import numpy
from scipy.io import wavfile

# %%
angry = []
for root, dirs, files in os.walk(r'Augmentation/angry/'):
    for file in files:
        if file.endswith('.wav'):
            angry.append(file)
calm = []
for root, dirs, files in os.walk(r'Augmentation/calm/'):
    for file in files:
        if file.endswith('.wav'):
            calm.append(file)
disgust = []
for root, dirs, files in os.walk(r'Augmentation/disgust/'):
    for file in files:
        if file.endswith('.wav'):
            disgust.append(file)
fearful = []
for root, dirs, files in os.walk(r'Augmentation/fearful/'):
    for file in files:
        if file.endswith('.wav'):
            fearful.append(file)
happy = []
for root, dirs, files in os.walk(r'Augmentation/happy/'):
    for file in files:
        if file.endswith('.wav'):
            happy.append(file)
neutral = []
for root, dirs, files in os.walk(r'Augmentation/neutral/'):
    for file in files:
        if file.endswith('.wav'):
            neutral.append(file)
sad = []
for root, dirs, files in os.walk(r'Augmentation/sad/'):
    for file in files:
        if file.endswith('.wav'):
            sad.append(file)
surprised = []
for root, dirs, files in os.walk(r'Augmentation/surprised/'):
    for file in files:
        if file.endswith('.wav'):
            surprised.append(file)

# %%
n_steps = -1
for i in angry:
    y, sr = librosa.load('Augmentation/angry/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/angry/'+i+'_pm_1sl.wav' ,rate=sr,data=y_changed)
for i in calm:
    y, sr = librosa.load('Augmentation/calm/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/calm/'+i+'_pm_1sl.wav' ,rate=sr,data=y_changed)
for i in disgust:
    y, sr = librosa.load('Augmentation/disgust/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/disgust/'+i+'_pm_1sl.wav' ,rate=sr,data=y_changed)
for i in fearful:
    y, sr = librosa.load('Augmentation/fearful/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/fearful/'+i+'_pm_1sl.wav' ,rate=sr,data=y_changed)
for i in happy:
    y, sr = librosa.load('Augmentation/happy/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/happy/'+i+'_pm_1sl.wav' ,rate=sr,data=y_changed)
for i in neutral:
    y, sr = librosa.load('Augmentation/neutral/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/neutral/'+i+'_pm_1sl.wav' ,rate=sr,data=y_changed)
for i in sad:
    y, sr = librosa.load('Augmentation/sad/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/sad/'+i+'_pm_1sl.wav' ,rate=sr,data=y_changed)
for i in surprised:
    y, sr = librosa.load('Augmentation/surprised/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/surprised/'+i+'_pm_1sl.wav' ,rate=sr,data=y_changed)

# %%
n_steps = -2
for i in angry:
    y, sr = librosa.load('Augmentation/angry/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename='Final_Augmented/angry/'+i+'_pm_2sl.wav' ,rate=sr,data=y_changed)
for i in calm:
    y, sr = librosa.load('Augmentation/calm/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename='Final_Augmented/calm/'+i+'_pm_2sl.wav',rate=sr,data=y_changed)
for i in disgust:
    y, sr = librosa.load('Augmentation/disgust/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename='Final_Augmented/disgust/'+i+'_pm_2sl.wav',rate=sr,data=y_changed)
for i in fearful:
    y, sr = librosa.load('Augmentation/fearful/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename='Final_Augmented/fearful/'+i+'_pm_2sl.wav',rate=sr,data=y_changed)
for i in happy:
    y, sr = librosa.load('Augmentation/happy/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename='Final_Augmented/happy/'+i+'_pm_2sl.wav',rate=sr,data=y_changed)
for i in neutral:
    y, sr = librosa.load('Augmentation/neutral/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename='Final_Augmented/neutral/'+i+'_pm_2sl.wav',rate=sr,data=y_changed)
for i in sad:
    y, sr = librosa.load('Augmentation/sad/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename='Final_Augmented/sad/'+i+'_pm_2sl.wav',rate=sr,data=y_changed)
for i in surprised:
    y, sr = librosa.load('Augmentation/surprised/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename='Final_Augmented/surprised/'+i+'_pm_2sl.wav',rate=sr,data=y_changed)

# %%
n_steps = -2.5
for i in angry:
    y, sr = librosa.load('Augmentation/angry/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/angry/'+i+'_pm_2.5sl.wav' ,rate=sr,data=y_changed)
for i in calm:
    y, sr = librosa.load('Augmentation/calm/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/calm/'+i+'_pm_2.5sl.wav' ,rate=sr,data=y_changed)
for i in disgust:
    y, sr = librosa.load('Augmentation/disgust/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/disgust/'+i+'_pm_2.5sl.wav' ,rate=sr,data=y_changed)
for i in fearful:
    y, sr = librosa.load('Augmentation/fearful/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/fearful/'+i+'_pm_2.5sl.wav' ,rate=sr,data=y_changed)
for i in happy:
    y, sr = librosa.load('Augmentation/happy/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/happy/'+i+'_pm_2.5sl.wav' ,rate=sr,data=y_changed)
for i in neutral:
    y, sr = librosa.load('Augmentation/neutral/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/neutral/'+i+'_pm_2.5sl.wav' ,rate=sr,data=y_changed)
for i in sad:
    y, sr = librosa.load('Augmentation/sad/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/sad/'+i+'_pm_2.5sl.wav' ,rate=sr,data=y_changed)
for i in surprised:
    y, sr = librosa.load('Augmentation/surprised/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/surprised/'+i+'_pm_2.5sl.wav' ,rate=sr,data=y_changed)

# %%
n_steps = -3.5
for i in angry:
    y, sr = librosa.load('Augmentation/angry/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/angry/'+i+'_pm_3.5sl.wav',rate=sr,data=y_changed)
for i in calm:
    y, sr = librosa.load('Augmentation/calm/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/calm/'+i+'_pm_3.5sl.wav',rate=sr,data=y_changed)
for i in disgust:
    y, sr = librosa.load('Augmentation/disgust/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/disgust/'+i+'_pm_3.5sl.wav',rate=sr,data=y_changed)
for i in fearful:
    y, sr = librosa.load('Augmentation/fearful/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/fearful/'+i+'_pm_3.5sl.wav',rate=sr,data=y_changed)
for i in happy:
    y, sr = librosa.load('Augmentation/happy/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/happy/'+i+'_pm_3.5sl.wav',rate=sr,data=y_changed)
for i in neutral:
    y, sr = librosa.load('Augmentation/neutral/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/neutral/'+i+'_pm_3.5sl.wav',rate=sr,data=y_changed)
for i in sad:
    y, sr = librosa.load('Augmentation/sad/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/sad/'+i+'_pm_3.5sl.wav',rate=sr,data=y_changed)
for i in surprised:
    y, sr = librosa.load('Augmentation/surprised/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/surprised/'+i+'_pm_3.5sl.wav',rate=sr,data=y_changed)

# %%
n_steps = 1
for i in angry:
    y, sr = librosa.load('Augmentation/angry/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/angry/'+i+'_pm_1sh.wav',rate=sr,data=y_changed)
for i in calm:
    y, sr = librosa.load('Augmentation/calm/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/calm/'+i+'_pm_1sh.wav',rate=sr,data=y_changed)
for i in disgust:
    y, sr = librosa.load('Augmentation/disgust/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/disgust/'+i+'_pm_1sh.wav',rate=sr,data=y_changed)
for i in fearful:
    y, sr = librosa.load('Augmentation/fearful/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/fearful/'+i+'_pm_1sh.wav',rate=sr,data=y_changed)
for i in happy:
    y, sr = librosa.load('Augmentation/happy/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/happy/'+i+'_pm_1sh.wav',rate=sr,data=y_changed)
for i in neutral:
    y, sr = librosa.load('Augmentation/neutral/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/neutral/'+i+'_pm_1sh.wav',rate=sr,data=y_changed)
for i in sad:
    y, sr = librosa.load('Augmentation/sad/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/sad/'+i+'_pm_1sh.wav',rate=sr,data=y_changed)
for i in surprised:
    y, sr = librosa.load('Augmentation/surprised/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/surprised/'+i+'_pm_1sh.wav',rate=sr,data=y_changed)

# %%
n_steps = 2
for i in angry:
    y, sr = librosa.load('Augmentation/angry/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/angry/'+i+'_pm_2sh.wav',rate=sr,data=y_changed)
for i in calm:
    y, sr = librosa.load('Augmentation/calm/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/calm/'+i+'_pm_2sh.wav',rate=sr,data=y_changed)
for i in disgust:
    y, sr = librosa.load('Augmentation/disgust/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/disgust/'+i+'_pm_2sh.wav',rate=sr,data=y_changed)
for i in fearful:
    y, sr = librosa.load('Augmentation/fearful/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/fearful/'+i+'_pm_2sh.wav',rate=sr,data=y_changed)
for i in happy:
    y, sr = librosa.load('Augmentation/happy/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/happy/'+i+'_pm_2sh.wav',rate=sr,data=y_changed)
for i in neutral:
    y, sr = librosa.load('Augmentation/neutral/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/neutral/'+i+'_pm_2sh.wav',rate=sr,data=y_changed)
for i in sad:
    y, sr = librosa.load('Augmentation/sad/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/sad/'+i+'_pm_2sh.wav',rate=sr,data=y_changed)
for i in surprised:
    y, sr = librosa.load('Augmentation/surprised/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/surprised/'+i+'_pm_2sh.wav',rate=sr,data=y_changed)

# %%
n_steps = 2.5
for i in angry:
    y, sr = librosa.load('Augmentation/angry/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/angry/'+i+'_pm_2.5sh.wav' ,rate=sr,data=y_changed)
for i in calm:
    y, sr = librosa.load('Augmentation/calm/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/calm/'+i+'_pm_2.5sh.wav' ,rate=sr,data=y_changed)
for i in disgust:
    y, sr = librosa.load('Augmentation/disgust/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/disgust/'+i+'_pm_2.5sh.wav' ,rate=sr,data=y_changed)
for i in fearful:
    y, sr = librosa.load('Augmentation/fearful/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/fearful/'+i+'_pm_2.5sh.wav' ,rate=sr,data=y_changed)
for i in happy:
    y, sr = librosa.load('Augmentation/happy/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/happy/'+i+'_pm_2.5sh.wav' ,rate=sr,data=y_changed)
for i in neutral:
    y, sr = librosa.load('Augmentation/neutral/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/neutral/'+i+'_pm_2.5sh.wav' ,rate=sr,data=y_changed)
for i in sad:
    y, sr = librosa.load('Augmentation/sad/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/sad/'+i+'_pm_2.5sh.wav' ,rate=sr,data=y_changed)
for i in surprised:
    y, sr = librosa.load('Augmentation/surprised/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/surprised/'+i+'_pm_2.5sh.wav' ,rate=sr,data=y_changed)

# %%
n_steps = 3.5
for i in angry:
    y, sr = librosa.load('Augmentation/angry/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/angry/'+i+'_pm_3.5sh.wav',rate=sr,data=y_changed)
for i in calm:
    y, sr = librosa.load('Augmentation/calm/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/calm/'+i+'_pm_3.5sh.wav',rate=sr,data=y_changed)
for i in disgust:
    y, sr = librosa.load('Augmentation/disgust/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/disgust/'+i+'_pm_3.5sh.wav',rate=sr,data=y_changed)
for i in fearful:
    y, sr = librosa.load('Augmentation/fearful/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/fearful/'+i+'_pm_3.5sh.wav',rate=sr,data=y_changed)
for i in happy:
    y, sr = librosa.load('Augmentation/happy/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/happy/'+i+'_pm_3.5sh.wav',rate=sr,data=y_changed)
for i in neutral:
    y, sr = librosa.load('Augmentation/neutral/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/neutral/'+i+'_pm_3.5sh.wav',rate=sr,data=y_changed)
for i in sad:
    y, sr = librosa.load('Augmentation/sad/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/sad/'+i+'_pm_3.5sh.wav',rate=sr,data=y_changed)
for i in surprised:
    y, sr = librosa.load('Augmentation/surprised/'+i, duration=2.97)
    y_changed = librosa.effects.pitch_shift(y, sr, n_steps=n_steps)
    wavfile.write(filename= 'Final_Augmented/surprised/'+i+'_pm_3.5sh.wav',rate=sr,data=y_changed)

# %%
for i in angry:
    y, sr = librosa.load('Augmentation/angry/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=0.81)
    wavfile.write(filename= 'Final_Augmented/angry/'+i+'_speed_81.wav',rate=sr,data=y_changed)
for i in calm:
    y, sr = librosa.load('Augmentation/calm/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=0.81)
    wavfile.write(filename= 'Final_Augmented/calm/'+i+'_speed_81.wav',rate=sr,data=y_changed)
for i in disgust:
    y, sr = librosa.load('Augmentation/disgust/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=0.81)
    wavfile.write(filename= 'Final_Augmented/disgust/'+i+'_speed_81.wav',rate=sr,data=y_changed)
for i in fearful:
    y, sr = librosa.load('Augmentation/fearful/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=0.81)
    wavfile.write(filename= 'Final_Augmented/fearful/'+i+'_speed_81.wav',rate=sr,data=y_changed)
for i in happy:
    y, sr = librosa.load('Augmentation/happy/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=0.81)
    wavfile.write(filename= 'Final_Augmented/happy/'+i+'_speed_81.wav',rate=sr,data=y_changed)
for i in neutral:
    y, sr = librosa.load('Augmentation/neutral/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=0.81)
    wavfile.write(filename= 'Final_Augmented/neutral/'+i+'_speed_81.wav',rate=sr,data=y_changed)
for i in sad:
    y, sr = librosa.load('Augmentation/sad/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=0.81)
    wavfile.write(filename= 'Final_Augmented/sad/'+i+'_speed_81.wav',rate=sr,data=y_changed)
for i in surprised:
    y, sr = librosa.load('Augmentation/surprised/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=0.81)
    wavfile.write(filename= 'Final_Augmented/surprised/'+i+'_speed_81.wav',rate=sr,data=y_changed)

# %%
for i in angry:
    y, sr = librosa.load('Augmentation/angry/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=1.07)
    wavfile.write(filename= 'Final_Augmented/angry/'+i+'_speed_107.wav',rate=sr,data=y_changed)
for i in calm:
    y, sr = librosa.load('Augmentation/calm/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=1.07)
    wavfile.write(filename= 'Final_Augmented/calm/'+i+'_speed_107.wav',rate=sr,data=y_changed)
for i in disgust:
    y, sr = librosa.load('Augmentation/disgust/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=1.07)
    wavfile.write(filename= 'Final_Augmented/disgust/'+i+'_speed_107.wav',rate=sr,data=y_changed)
for i in fearful:
    y, sr = librosa.load('Augmentation/fearful/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=1.07)
    wavfile.write(filename= 'Final_Augmented/fearful/'+i+'_speed_107.wav',rate=sr,data=y_changed)
for i in happy:
    y, sr = librosa.load('Augmentation/happy/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=1.07)
    wavfile.write(filename= 'Final_Augmented/happy/'+i+'_speed_107.wav',rate=sr,data=y_changed)
for i in neutral:
    y, sr = librosa.load('Augmentation/neutral/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=1.07)
    wavfile.write(filename= 'Final_Augmented/neutral/'+i+'_speed_107.wav',rate=sr,data=y_changed)
for i in sad:
    y, sr = librosa.load('Augmentation/sad/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=1.07)
    wavfile.write(filename= 'Final_Augmented/sad/'+i+'_speed_107.wav',rate=sr,data=y_changed)
for i in surprised:
    y, sr = librosa.load('Augmentation/surprised/'+i, duration=2.97)
    y_changed = librosa.effects.time_stretch(y, rate=1.07)
    wavfile.write(filename= 'Final_Augmented/surprised/'+i+'_speed_107.wav',rate=sr,data=y_changed)
